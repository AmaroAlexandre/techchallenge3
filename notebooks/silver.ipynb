# %% [markdown]
# # Silver
#
# Cada ano o CSV vem com nome de coluna diferente. Aqui eu padronizo, viro a faixa salarial em número e marco python/sql/aws/ia.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()))

from src.spark_utils import build_spark
from src.transform_silver import transform_silver

spark = build_spark("notebook-silver")
silver = transform_silver(spark)
silver.printSchema()
silver.groupBy("survey_year").count().orderBy("survey_year").show()
spark.stop()
