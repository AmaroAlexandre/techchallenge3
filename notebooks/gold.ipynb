# %% [markdown]
# # Gold
#
# Tabelas que o Athena lê. No lab o crawler aponta pra pasta gold no S3; as queries estão em `sql/consultas.sql`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()))

from src.spark_utils import build_spark
from src.transform_gold import transform_gold

spark = build_spark("notebook-gold")
tables = transform_gold(spark)
tables["overview"].show()
tables["tech_adoption"].filter("survey_year = 2025").orderBy("adoption_pct", ascending=False).show()
spark.stop()
