# %% [markdown]
# # Bronze
#
# CSV cru das três últimas State of Data. `survey_year` é o ano da coleta.
#
# https://www.kaggle.com/datahackers/datasets

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()))

from src.config import BRONZE_DIR, DATASETS
from src.ingest_bronze import ingest_bronze

paths = ingest_bronze()
for p in paths:
    print(p, p.stat().st_size)

# %% [markdown]
# No AWS Academy o equivalente é o upload no S3: `s3://bucket/lake/bronze/survey_year=YYYY/survey.csv`.
